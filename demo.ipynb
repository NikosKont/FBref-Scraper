# %%
import scraper

# %% [markdown]
# Available stats are:
# 'stats', 'keepers', 'keepersadv', 'shooting', 'passing', 'passing_types',
# 'gca' (goal/shot creation), 'defense', 'possession', 'playingtime', 'misc' <br>
# Can also be seen with scraper.available_stats()

# %%
scraper.available_stats()
# Out:
# ('stats',
#  'keepers',
#  'keepersadv',
#  'shooting',
#  'passing',
#  'passing_types',
#  'gca',
#  'defense',
#  'possession',
#  'playingtime',
#  'misc')

# %% [markdown]
# 9: Premier League ID

# %%
df = scraper.get_player_stats('shooting', 9)
# Out:
# Getting data from https://fbref.com/en/comps/9/shooting/...
# Done.

# %%
df.sort_values(by=['np:G-xG'], ascending=False, inplace=True)
df.reset_index(drop=True, inplace=True)
df.head(15)
# Out:
#                Player Nation    Pos            Squad  Age  Born   90s  Gls  \
# 0          Harry Kane    ENG     FW        Tottenham   29  1993  37.8   30
# 1      Erling Haaland    NOR     FW  Manchester City   22  2000  30.8   36
# 2          Martinelli    BRA     FW          Arsenal   21  2001  31.0   15
# 3     Roberto Firmino    BRA  FW,MF        Liverpool   30  1991  13.5   11
# 4          Phil Foden    ENG     FW  Manchester City   22  2000  20.5   11
# 5     Martin Ødegaard    NOR     MF          Arsenal   23  1998  34.7   15
# 6             Rodrigo    ESP  FW,MF     Leeds United   31  1991  21.5   13
# 7   James Ward-Prowse    ENG     MF      Southampton   27  1994  37.5    9
# 8       Harvey Barnes    ENG  FW,MF   Leicester City   24  1997  30.1   13
# 9         Pascal Groß    GER  MF,DF         Brighton   31  1991  36.0    9
# 10      Dwight McNeil    ENG  FW,MF          Everton   22  1999  27.8    7
# ...
