# %%
import scraper

df = scraper.getPlayerStats('shooting', '9')
# Out:
# Getting data from https://fbref.com/en/comps/9/shooting/

# %%
df.sort_values(by=['np:G-xG'], ascending=False, inplace=True)
df.head(15)
# Out:
#                 Player Nation    Pos            Squad     Age  Born   90s  \
# 195     Erling Haaland    NOR     FW  Manchester City  22-192  2000  17.2
# 237         Harry Kane    ENG     FW        Tottenham  29-185  1993  20.8
# 281     James Maddison    ENG  MF,FW   Leicester City  26-067  1996  12.4
# 15      Miguel Almirón    PAR     FW    Newcastle Utd  28-353  1994  18.4
# 480  James Ward-Prowse    ENG     MF      Southampton  28-089  1994  20.0
# 391            Rodrigo    ESP  FW,MF     Leeds United  31-329  1991  14.4
# 157         Phil Foden    ENG  FW,DF  Manchester City  22-246  2000  11.6
# 155    Roberto Firmino    BRA  FW,MF        Liverpool  31-119  1991  10.3
# 188        Pascal Groß    GER  MF,DF         Brighton  31-228  1991  18.2
# 293         Martinelli    BRA     FW          Arsenal  21-225  2001  17.9
# 500      Wilfried Zaha    CIV  FW,MF   Crystal Palace  30-080  1992  18.5
# 213    Pierre Højbjerg    DEN     MF        Tottenham  27-177  1995  19.8
# ...
