# %%
import scraper

# 9: Premier League ID
# available stats are:
# 'stats', 'keepers', 'keepersadv', 'shooting', 'passing', 'passing_types',
# 'gca' (goal/shot creation), 'defense', 'possession', 'playingtime', 'misc'

df = scraper.getPlayerStats('shooting', '9')
# Out:
# Getting data from https://fbref.com/en/comps/9/shooting/

# %%
df.sort_values(by=['np:G-xG'], ascending=False, inplace=True)
df.reset_index(drop=True, inplace=True)
df.head(15)
# Out:
#                Player Nation    Pos            Squad     Age  Born   90s  Gls  \
# 0      Erling Haaland    NOR     FW  Manchester City  22-192  2000  17.2   25
# 1          Harry Kane    ENG     FW        Tottenham  29-185  1993  20.8   16
# 2      James Maddison    ENG  MF,FW   Leicester City  26-067  1996  12.4    7
# 3      Miguel Almirón    PAR     FW    Newcastle Utd  28-353  1994  18.4    9
# 4   James Ward-Prowse    ENG     MF      Southampton  28-089  1994  20.0    5
# 5             Rodrigo    ESP  FW,MF     Leeds United  31-329  1991  14.4   10
# 6          Phil Foden    ENG  FW,DF  Manchester City  22-246  2000  11.6    7
# 7     Roberto Firmino    BRA  FW,MF        Liverpool  31-119  1991  10.3    7
# 8         Pascal Groß    GER  MF,DF         Brighton  31-228  1991  18.2    6
# 9       Wilfried Zaha    CIV  FW,MF   Crystal Palace  30-080  1992  18.5    6
# 10         Martinelli    BRA     FW          Arsenal  21-225  2001  17.9    7
# 11    Pierre Højbjerg    DEN     MF        Tottenham  27-177  1995  19.8    4
# 12   Leandro Trossard    BEL  FW,MF         Brighton  28-056  1994  14.6    7
# 13  Rodrigo Bentancur    URU     MF        Tottenham  25-218  1997  15.0    4
# 14    Martin Ødegaard    NOR     MF          Arsenal  24-043  1998  16.9    8
#
#     Sh  SoT  ...  G/SoT  Dist  FK  PK  PKatt    xG  npxG  npxG/Sh  G-xG  \
# 0   70   36  ...   0.58  12.6   0   4      4  16.9  13.7     0.20   8.1
# 1   75   33  ...   0.42  15.6   2   2      3  11.8   9.4     0.13   4.2
# 2   40   13  ...   0.54  20.7   7   0      0   2.6   2.6     0.07   4.4
# 3   46   14  ...   0.64  17.0   0   0      0   5.4   5.4     0.12   3.6
# 4   21    9  ...   0.56  25.6   9   0      1   2.6   1.6     0.08   2.4
# 5   52   19  ...   0.47  16.4   2   1      1   6.5   5.7     0.11   3.5
# 6   28   14  ...   0.50  14.2   0   0      0   3.7   3.7     0.13   3.3
# 7   33   20  ...   0.35  12.7   0   0      0   4.2   4.2     0.13   2.8
# 8   20   10  ...   0.60  16.0   0   0      0   3.3   3.3     0.16   2.7
# 9   39   16  ...   0.38  17.6   0   0      2   5.1   3.3     0.09   0.9
# 10  49   17  ...   0.41  16.6   2   0      0   4.3   4.3     0.09   2.7
# 11  22    7  ...   0.57  21.0   0   0      0   1.4   1.4     0.06   2.6
# 12  38   17  ...   0.41  15.0   0   0      0   4.4   4.4     0.12   2.6
# 13  12    7  ...   0.57  15.5   0   0      0   1.4   1.4     0.12   2.6
# 14  48   15  ...   0.53  19.0   5   0      0   5.5   5.5     0.11   2.5
#
#     np:G-xG
# 0       7.3
# 1       4.6
# 2       4.4
# 3       3.6
# 4       3.4
# 5       3.3
# 6       3.3
# 7       2.8
# 8       2.7
# 9       2.7
# 10      2.7
# 11      2.6
# 12      2.6
# 13      2.6
# 14      2.5
#
# [15 rows x 24 columns]
